# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# spacy for lemmatization
import spacy

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

# %%
df = pd.read_json('NewYorkState_hotels_reviews.json', lines=True)
df.sample(n=2)
# Out:
#        Cleanliness Comfort Facilities FreeWifi GivenScore  \
# 291624         [8]   [7.2]      [7.2]      [8]  [\n9.2\n]
# 91046          [9]   [8.7]      [8.6]      NaN  [\n8.8\n]
#
#                                       Heading  \
# 291624  [Great value for money and location!]
# 91046                             [Location.]
#
#                                 HotelName Location  \
# 291624                [SoHo Garden Hotel]    [8.6]
# 91046   [RIU Plaza New York Times Square]    [9.5]
#
#                                            NegativeReview   NumReviewGiven  \
# 291624  [The first room we got in didn't have a remote...  [\n9 reviews\n]
# 91046                                                 NaN   [\n1 review\n]
#
#                                            PositiveReview  \
# 291624  [When the neighbour was really noisy, the staf...
# 91046                     [Location. Breakfast included.]
#
#                                                   SelfTag  Staff  \
# 291624  [\n,  Leisure trip\n, \n,  Couple\n, \n,  Delu...  [8.5]
# 91046   [\n,  Leisure trip\n, \n,  Group\n, \n,  Delux...  [8.6]
#
#                           StayDate UserAgeGroup       UserCountry  \
# 291624    [\nStayed in May 2018\n]         [\n]          [France]
# 91046   [\nStayed in March 2018\n]         [\n]  [United Kingdom]
#
#             UserName ValueForMoney
# 291624  [Amaurea460]         [7.4]
# 91046         [Anne]           [8]

# %%
all_pos_rev = [line[0] for line in df['PositiveReview'] if str(line)!='nan']
all_neg_rev = [line[0] for line in df['NegativeReview'] if str(line)!='nan']

# %%
df['AllReviews']=np.nan
df['AllReviews'][df['NegativeReview'].isnull()]=df['PositiveReview'][df['NegativeReview'].isnull()]
df['AllReviews'][df['PositiveReview'].isnull()]=df['NegativeReview'][df['PositiveReview'].isnull()]
all_rev = [rev[0] for rev in df['AllReviews'] if str(rev)!='nan']
# Out:
# /home/argha/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
all_rev
# Out:
# ['Desk staff excellent. Friendly and helpful. Breakfast was great. Bed very comfortable and loved the living/kitchenette space in addition to the bedroom.',
#  'The fact that we all were woken around 2am for a fire alarm. No staff came out to make contact with anybody outside as to what was going on nor that it was clear to go back inside!',
#  'The rooms were clean comfortable and spacious. The pool and hot tub were clean as well. Courtyard was beautiful with fire pit.\rDaily breakfast was good. Close to all activities.',
#  'Beautiful, clean and comfortable hotel! Close to the concert venue (SPAC) - within walking distance. Staff was friendly and so helpful!\nI would absolutely recommend this property and will definitely stay again!',
#  "Bed was very soft and comfortable. Room was nice and large, great with two TV's and a sofa. Food was fine but could have been warmer. Choices were very good and healthy. Liked to have tried the barbeque but were at my nieces for dinner.",
#  "This property was amazing!  Beautifully maintained; we took full advantage of the fitness facility, pool and, since we were traveling with kids, the laundry room!  Wonderful and attentive staff, and convenient location -- five minutes from the heart of beautiful Saratoga Springs!  Can't say enough great things about the property or our stay.",
#  'The suite was spacious, clean, and nicely-decorated.  Bed and pillows were comfortable, and our room was quiet.  The staff was quite friendly and helpful.  Breakfast was good, too.',
#  'I  definitely like the location close to everything the décor was in good taste and the service was great . only defeat that maybe next time fresh omelets can be added to the menu.',
#  'Dinner and happy Hour were exceptional.  The outdoor fire pit was a great feature.  The price was extremely good and the staff was outstanding.  We would consider for a large group outing we do annually in August if the rates remain good.',
#  "Absolutely wonderful hotel! Staff went out of their way to be kind and helpful. Our first set of keys would not work as everything was brand new, but the staff made all the arrangements to get us into our room quickly and comfortably! The hotel is beautiful! Rooms are very spacious and generous in size! TV's and outlets everywhere! GREAT LOCATION!",
#  'EVERYTHING!!!!',
#  'The breakfast was complete and delicious, especially the eggs and bacon',
#  'Everything ',
#  'It was outstandingly clean and welcoming! The staff was phenomenal and we couldn’t have been more pleased with our stay!\n',
#  'Staff friendly upon checkin and throughout stay',
#  'Beds were comfy, pool was great (a  little chilly), breakfast had a lot of choice, room was spacious!',
#  'The beds are very comfortable. Great pool and hot tub. Lounge area is bright and well appointed.',
#  'Better pillows',
#  'We were very impressed☄️The supper was so welcome to us as an older couple traveling! We did not have to go out searching for some place to eat!',
#  'The breakfast was good \rthe bed was amazing',
#  'everything about this hotel was good to great',
#  'So conveniently located. ',
#  'Room cd had been a little fresher regarding smell.',
#  'New, clean, well supplied,  wry good breakfast, staff friendly helpful and efficient',
#  'Was really a great experience, nice property, spacious suite, would come again.',
#  'Front desk staff friendly, knowledgeable, and welcoming.  Beds and pillows very comfortable.',
#  'The staff was amazingly helpful and the room was very clean. Great price for the amenities! ',
#  'Perfect in every way.',
#  'We loved it, outstanding service, good breakfast, clean and confortable, shuttle service to city center. Would come again',
#  'Staff extremely accommodating',
#  'Front desk staff were very nice.. came for daughter',
#  'The pool was super, with spa whirlpool.',
#  'Everything! I’ve stayed in numerous top rated hotels across the States and Adelphi Hotel beats them all. Every one of your staff is very professional and friendly.  My daughter and i came to Saratoga because It was my daughters 27th birthday .  We are from Buffalo N.Y.  My daughter was on a private rowing team in buffalo and always came to Saratoga for regattas.  Unfortunately, she was  always busy at the water so she never saw much of Saratoga.  For my daughters birthday I took her on “A Mystery Birthday Ride” to Saratoga. She didn’t figure it out where she I was taking her until we turned on to Broadway.  To say she was thrilled is an understatement!  Then when we checked in at your hotel and she found a birthday cake in our room she was in shock.  Her exact words were.... I’m blown away that this by hotel and , that they gave me a birthday cake!!!  I can’t thank you enough for helping me make this weekend the BEST 27th birthday .  When we walked in and out of the quaint stores on Broadway every so often she would turn to me and say ... I’m still in shock we are here and I got a cake.  Just watching her glow with such a smile made MY time in Saratoga extra special!  Thank you from the bottom of my heart .\nSincerely, Sue & Bri Reinecke ',
#  'The beds were so comfortable, the room was beautiful. Loved the bathroom, towel warmer and all the extras!',
#  'Food and service was Excellent! Highly recommend staying here.',
#  'Loved the room and hotel amenities. Very spacious room.',
#  'Gorgeous Hotel and the room was equally amazing, ..... very accommodating staff!',
#  'It was above and beyond everything was perfect, cozy, quiet, view, perfect location- definitely would stay again! Everything we needed!',
#  'Everything in the room was beautiful, the bed was super comfortable, and the staff was attentive and friendly.',
#  'Luxurious! BEST BEDS!!!!!!!',
#  'Friendly greeting from the owner Keith, He took us to our room and showed us around the premises. The bed was extremely comfortable and the free breakfast was amazing.',
#  'very friendly staff, super atmosphere and well situated. We really enjoyed our stay and I can strongly recommend the Whitby Hotel in New York.',
#  'There was no Coffee maker in the room. ',
#  'Loved the individuality of the interior!!',
#  'Housekeeping and breakfast ',
#  "Definitely one of the better 5 Star Hotel's in NYC, would highly recommend !",
#  'A beautifully designed hotel with the highest quality staff',
#  'Nice service and wonderful hotel. Love the room so much, very comfortable and clean! Few steps to 5th avenue and Central Park, very convenient. ',
#  'Everything about this place is wonderful. The service was personal and at the highest level. Really enjoyed our stay.',
#  'Beautiful rooms .Beautiful hotel .',
#  'I loved the feel and uniqueness of the hotel. My room was superb and the decorations so interesting. But the staff sealed the stay for me. ',
#  'everything!',
#  'excellent location! Very helpful staff, quite a hidden gem in the midtown.',
#  'Unfähiges Management ',
#  'Bed not comfortable.',
#  'The rooms were beautifully decorated and maintained during our stay.\rThe concierge team were world class.',
#  'There truly was nothing not to like.',
#  'Water temperature in my shower would fluctuate between mild and semi hot, even when cranked to max temperature',
#  'It was all great rooms comfortable great food great service. One of the best hotels Ive stayed in.',
#  'Rate was not as quoted by booking . Com',
#  'The screening room, the honor bar',
#  'Everything about our stay was exceptional.  The breakfast was incredible, especially the omelet station.  We enjoyed the complimentary reception in the evening.  The drinks were great and the food was delicious.',
#  'I was impressed by the beautiful overall design of the hotel....the included breakfast was fantastic as was the chef Rahniem (sp?) and the happy hour was a unexpected treat. I would definitely say this hotel was at the top of my list for favorite places to stay.',
#  "What a wonderful experience staying at Embassy Suites Saratoga! The rooms were spacious, updated & clean. The staff was friendly, courteous & informative to our needs. Walking distance to downtown & a bit longer walk to the SPAC. I would highly recommend staying here if you're visiting!",
#  'The room was incredibly clean and well appointed. From the moment we arrived, the staff was super friendly, helpful, and patient. The front desk staff at this property was the definition of exceptional customer service! We really loved the complimentary breakfast and cocktail hour during our stay. Everything was fantastic and would recommend to anyone looking to stay in Saratoga Springs!',
#  'The breakfast was made to order & delicious. The location was perfect - walking distance to restaurants & activities. Very friendly & clean.',
#  'The room was a lot bigger than we expected and it had a wonderful view of the town. Everything was just beautiful, and the complimentary breakfast was delicious.',
#  'Thank you for the flexibility of a late checkout. \rWe had a last minute change with college interviews and when I asked for a late checkout I was prepared to be charged. I was pleasantly surprised that there was no extra charge and our checkout was very rapid and the staff extremely kind and helpful  for',
#  'The facility itself is marvelous, very modern, but warm.  The staff is exceptional, friendly and gracious, always ready to be of assistance with a smile.',
#  "Great property. It's located inside a small shopping center, which I've never seen before. So literally right next door is a 24 CVS, a REALLY good liquor store, and a nail salon. All of the things I need when I'm relaxing for a weekend. The staff is super friendly. The complimentary breakfast is EVERYTHING! Rooms are nice and big, cleans and comfortable. Will definitely come back.",
#  'Cocktail reception was awesome. Bartender makes a fantastic margarita. Breakfast omelette is perfectly made. Everyone is so friendly. Hotel is fantastic.',
#  "The hotel is close to Destiny USA mall and I-81. Beautiful hotel. Beds are very comfortable. The free breakfast was superior to most hotels I've stayed at. ",
#  'Everything about this hotel is 5 star!!! Exceptionally clean.  But overall the staff was amazing. Polite, kind, caring, helpful and professional at all levels\n',
#  'Staff were outstanding and hotel was spotless. \rWe had a large room with 2 queen beds and a nice bathroom with a walk in shower. They arranged free transportation to the airport. I highly recommend!',
#  'A very nice spacious room and excellent beds. The bathroom was also spacious including the shower. The front desk recommended a very good Italian restaurant. We would like to return to the area just for that reason.',
#  'The pillows and bed were super comfy.  This is a brand new modern building that is exceptionally clean.  The pool and hot tub were great and the workout room was spacious with windows to view the pool and outdoor area which was nice. \rLoved the free cookies, popcorn, tea and coffee.',
#  'Bed and pillow were excellent.  Wanted to bring it home with me.  Lots of room.   New and clean facility.   \rWould stay here again when traveling in this area.  It',
#  'The people were very friendly and helpful. The breakfast was amazing. The room was very comfortable. It was a wonderful stay.',
#  'The front staff employee had to be the most caring person, I can’t say enough about her .',
#  'Wonderful complimentary breakfast and freindly courteous staff',
#  'Staffs are very nice! \nRooms are so comfortable.',
#  'Great, central location. Bright & clean lobby and rooms. Very friendly staff, very good free breakfast! Had a great nights sleep!',
#  'The hotel staff was very helpful and friendly.  The room was comfortable and clean.  Definitely would stay again.',
#  'Beautiful room that was very comfortable.  Beautiful bathroom.  Very clean',
#  'The bed was a little hard.',
#  'The staff were very nice and were their if we needed anything. The pool was very clean and it was a wonderful stay',
#  'Everything was exceptional except for the fact there were no bathtubs for my little four-year-old wanted to take a bath very bad',
#  'Very clean, specious, friendly staff, free parking, free WiFi, bets are not allowed, free tea and coffee counter at the lobby.',
#  'Breakfast was excellent Loved the oatmeal',
#  'Fresh and clean. Pleasant decor. Good breakfast.',
#  'The staff and cleanliness were exceptional.',
#  'Beds too small',
#  'Staff was very friendly and welcoming. When we walked into our room it even smelled clean. Great hotel.',
#  'Appears to be new, staff knowledgeable about local restaurants, well built,. No noise when people walk in halls or above you',
#  'Beautiful hotel.  Rooms were gorgeous.  Comfy beds.',
#  'Staff was amazing. Incredibly friendly and helpful. Hotel is beautiful. Feels brand new',
#  'Very clean. Beautiful room. Great breakfast!',
#  'hot tub motor weak',
#  'Breakfast was very good',
#  'newly renovated hotel with convenient location. very clean!',
#  'The ladies in the front desk were very accommodating!',
#  'breakfast could have had a bigger variety',
#  'Good breakfast, new hotel very clean',
#  'The place is new.......great cont breakfast',
#  'The hotel was brand new and the breakfast bar delish!',
#  'Love staying at the Hampton! Perfect location and beautiful!',
#  'Staff was very welcoming and helpful. Air conditioning was quiet and effective.',
#  'Good coffee, and I liked the popcorn',
#  'this was pleasant surprise. great staff and food. \rrooms were clean and we got good rest.',
#  'I liked having a large shower stall instead of a tub combo!',
#  "I love this hotel.   I've been to others in the area, but will now always stay in this hotel.   The staff were not just friendly,  they were authentic.  Staff obviously enjoy their job and feel valued.  Many went out of their way to ensure my stay was great.  Great way to spend my birthday - thanks !",
#  'The property was clean, comfortable and all staff were friendly. The breakfast in the morning was excellent. I highly recommend everyone to stay here just once. ',
#  'Was very noisy on Friday evening...which is unusual. Loud music coming from below our room - must have been an event going on....we were on the second floor.  It did quiet down shortly before 11.',
#  'Our room was quiet which was so nice because so many hotel rooms are not. It also had a mini fridge which is convenient for keeping bottled water. Providing a free breakfast buffet was an added bonus.',
#  'Room design was very pleasing and provided many small but welcome conveniences. Pool & fitness room were clean & well maintained, equipment was excellent. Design for Accessibility throughout hotel, from pool chair-lift to hearing-impaired room access was impressive.',
#  'Spring Hills suits is my favorite Hotel chain . Modern Rooms, with space for work. The hotel is Clean and always feels very new. The Breakfast never disappoints and the lobby is comfortable and spacious.',
#  'Roomy room, spacious, clean design.  We did not partake of breakfast, but it looked really nice and lobby was very spacious, yet with little spots here and there for small groups.',
#  'Rooms are very spacious, with lots of storage space. The closet is huge. The Paul Mitchell toiletries are a nice touch.\rExcellent breakfast with plenty of choices.',
#  'I thoroughly enjoyed my time at the Springhill Suites. The room was,beautiful. The hotel itself magnificent , clean, friendly staff and the breakfast was wonderful. We had approx. 8 rooms at the hotel and we all had a fabulous stay there.',
#  'The whyfi',
#  'New hotel with comfortable beds, sofa and lots of space. Friendly staff. Would stay again!',
#  'Great value & staff!',
#  'The beds were very comfortable the washer and dryer came in handy everything was amazing ‼️',
#  'Everything was perfect, delicious breakfast, great pool, laundry room, great staff, free parking. Have no complains whatsoever ',
#  'Excellent. Clean comfortable',
#  'Convenience.  Space for seating in lobby for breakfast.  Staff very welcoming and helpful.',
#  'Comfy bed',
#  'Large and clean rooms, next to a lake, close to Cold Spring, good meal',
#  'Great breakfast and staff was very professional.',
#  'Did not use',
#  'The room was very nice, spatious and pretty. The bed was incredibly confortable! Great breakfast! And the price was very fair.',
#  'Nice central location',
#  'Very noisy on Saturday night.',
#  'New, modern, clean, large rooms with excellent hot breakfast.',
#  'Food looks fabulous.',
#  'Very clean. The staff was friendly. Really beautiful and comfortable room. Heated indoor pool. Bar with good food. Breakfast was wonderful. ',
#  'Tried to charge wrong price and were givem wrong room',
#  'Very professional and accomidating staff.  Physical plant is excellent.',
#  'Clean, comfortable, quiet, beautiful large breakfast area with a superb large breakfast with many choices of good fresh food',
#  'The staff was professional, personable, and prompt.',
#  'clean, spacious room, comfortable bed, good shower, new facility',
#  'Love the spacious luxury of the room.  Breakfast was outstanding.  Very comfortable bed and pillows.  Loved everything about the hotel.',
#  'Best value in town! Between the full breakfast, the comlimentary dinner three nights a week, the suite-size kitchen with a full refrigerator, and the great location, the price can’t be beat!',
#  'I could live here. The room was amazing and the kitchen was spacious. The staff was so friendly. The pool and hot tub were so amazing it may have made the stay. Super close to the mall. The staff went above and beyond to make the room romantic with rose petals and sparkling wine.',
#  'Was Clean, Fancy for the price loved what it comes with ( Aka free breakfast and dinner too during the week) Staff were awesome and love the energy efficiency of the hotel key/Power system!',
#  "It was a great experience.  I really wanted to highlight the staff, especially Jackie at the front desk.  Super friendly, always going above and beyond for us to enjoy our stay.  This is why I always chose  Staybridge when i'm in Albany.",
#  'The facilities are great.  Excellent location, great gym, and the breakfast is awesome but above else they staff is super friendly and courteous and always willing to accommodate my requests.  I stay at this hotel every time i am in Albany which is usually 1-2 a month.  I will not stay anywhere else!',
#  'I have to say, this property was clean! There are so many accomodating ammenities. We had a full kitchen, they have storage rooms for guests and free laundry! The fitness center is open 24hours as well as the laundry room. Great breakfast,  so many options for a hotel. Will stay again!',
#  'Nothing.This property was well managed from the time we checked in until check out.All the staff was very nice and went out of their way to make our stay enjoyable.',
#  "The hotel is very hard to find if you're not familiar with the area.  The address is 34 Wolf Road, but it is not on Wolf road.  They should give better directions",
#  'Absolutely loved my stay at Staybridge.  Great facility in a great location.   Friendly staff and family friendly indeed.  Breakfast provided was amazing and all the facilities such as pool, gym are also amazing.  My kids had such a great time there.  Will def be returning again.',
#  'A tad awkward walking to the pool through the main lobby. A elevator in the back would be nice',
#  'Beautiful clean hotel with friendly staff and we could walk right to the mall. ',
#  'Social hour was great',
#  'How clean everything is was',
#  'The staff was GREAT',
#  'Beautiful room, spacious, clean.   Fantastic pillows!',
#  'This was an unexpected surprise.  It was such a great place to stay!',
#  'Comfortable room, great laundry facilities ',
#  'I loved everything hotel was amazing I am sure I will be going back in the future',
#  'Right in the shopping mall area.  Large room with separate kitchen.  ',
#  'Everything',
#  'Very comfortable bed. The location was perfect for us. Lots of malls around and easy from the highway.',
#  'The suites had great space with the kitchenette and couch.',
#  'Amazing and friendly staff overall facility exceeded All my expectations definitely a destination I would recommend and also stay at again',
#  "Couldn't use the jacuzzi. Every time we went it was crowded with children.",
#  'Everything was wonderful including the free breakfast!!',
#  'The complimentary buffet breakfast was a plus !',
#  'The cleanliness, great staff attitude, and great location and price.',
#  'The staff',
#  'Customer service',
#  'Wonderful experience. Can’t wait to stay again!',
#  'The rooms were clean with a perfect setup.\n',
#  'It was comfortable clean everyone was friendly provided a full breakfast it was all eco friendly it was nice anything I expected it provided for me',
#  'The mattress was very comfortable, the kitchen in our suite was equipped with everything, the complimentary breakfast was quite good.',
#  'Food and wine or beer were included as well as breakfast. The room was spacious, spotless, comfortable and we couldn’t ask for anything more.',
#  'The space is big enough and comfortable ',
#  'Breakfast was very clean and  large variety of item.',
#  'The kitchen was great, and the room was very comfortable',
#  'The room was clean, and the interior was beautiful. We stayed in the Tiffany room, and it was well designed. Excellent breakfast and very friendly staff. Also, there are a river and a lovely garden in the backyard. \rGood place for dinner is across the corner.',
#  'Highly recommended! The Roxbury is a really cool & quirky place with unique rooms. To make things perfect we were always taken care of by super nice and friendly staff!',
#  "We loved the theme King rooms.  We stayed in Angel Hair, and as a big Charlie's Angel fan, I got a big kick out of it!  Also, today we took a tour of some of the other rooms and they are so fun and fanciful.  We hope to go back and stay in a different room next time.  Also, all of the staff were so friendly and sweet, it made our experience even better!",
#  'The facilities were so cute.  All the rooms were themed based.  We stayed in the "Miss Kitty Saloon."  When we arrived we were greeted by the manager Ms Susie.  Very pleasant and helpful.  We were upgraded to a suite.  We had two bedrooms, 1-1/2 baths.  Wine and beer were stocked in the full frig if we wanted to endulge.  We actually received a complimentary bottle of wine.  We loved it and would recommend it to anyone.  We headed out at 5:30 AM so weren\'t able to feast on the breakfast that was available beginning at 8 AM.',
#  'Love the funky vibe of this hotel. Simple and elegant and in a beautiful area. Everyone there was very friendly and helpful. Love the spa and design touches throughout the property.',
#  'All!!!!!!',
#  'Room clean. Breakfast was tasty.',
#  'Beautiful, very clean and so comfortable. Loved the furniture, the setup and the staff.\rReally perfect.  Thank you so much.',
#  'Property was clean, the front staff was very friendly. ',
#  'Breakfast is always great!!!!',
#  'The pool',
#  'Every thing , it’s exceptional hotel , one of the best experience , best hotel employees are there , comfort , clean , good location',
#  'Noise of fans that ran all night. Other than that we enjoyed our stay',
#  'Large clean rooms.  All staff went above and beyond to be kind and helpful.',
#  'Breakfast was on point.',
#  'I liked the complimentary dinner buffet:  fresh greens, balsamic dressing, real bleu cheese and a wonderful red wine!',
#  'Great suite, super clean, comfy king bed, great buffet breakfast. Very friendly front desk staff.',
#  'Friendly, helpful staff. Great amenities and room. Fabulous breakfast.',
#  'great hotel ,good food very clean  and great staff.',
#  'Indoor pool, evening meal mon -  thu, located next to a mall',
#  'Bed was a little lumpy',
#  'The desk staff was very professional and friendly, very welcoming after a long drive.',
#  'The room was really nice',
#  'the new clean room and the size of the room also the breakfast was great',
#  'Stayed only for a night.  Room was quiet & comfortable.  Staff was great.  Also enjoyed the Italian food at Cremaldis down the street.  Very pleasant stay overall.',
#  'The bed was very comfortable and the staff were very friendly and helpful. Me and my family went to the swimming pool and the fitness room and had a lot of fun. Thank you',
#  'The room was very comfortable, nicely designed and clean.  The bathroom was large with a beautiful shower.  We enjoyed the breakfast buffet with its wide variety of hot or cold choices, fresh fruits or grab and go.  We had a great stay!',
#  'The breakfast was really good with alot of options they were qyucj to refill when something was out. The beds were very comfortable and the rooms where clean and well organized. The room was bigger then I expected and so was the bathroom.',
#  'The hotel was located close to where I needed to be, and convenient to the highway.  The staff was extra friendly and very helpful in changing my reservation, which saved me a fair amount of $$.  The room was clean, comfortable, and quiet.',
#  'Great location, quiet area. Room very comfortable & breakfast included. Bathroom massive lovely walk in shower. Coffee machine & microwave in Room, vending machines with food. Gym & pool. Recommend this hotel',
#  'Gym was great(a little small) but it got the job done. Close location to airport and other points of interest. Room was comfortable and clean. Well exceeded my expectations! Breakfast spread was awesome. I try not to spend more than $100 on hotels; this was slightly over but was worth it!',
#  'The room was as advertised and spacious. They accommodated our request for a suite by the pool and the room was quiet. We arrived before our check in time and they still let us check in.',
#  "New and very comfortable hotel. We've stayed here twice now on our way between Ohio and Maine. Nice bed, great shower. Better breakfast with more choices than a lot of chain hotels. Even had a good veggie sausage as an option! Coffee was good too. We plan to stay again on our next trip.",
#  'The front desk associate was very nice and remembered us from our last trip last spring. She did an exceptional job. I wish I could remember her name, she deserves to get credit for doing a great job.',
#  "Great room, great staff, great price. We stayed here twice in one week (on the way out and back on a trip we were taking), and both times everything was great. We didn't use the fitness room or the pool (although we did see it, and the pool was surprisingly small, like other Marriott properties we've seen recently--so I wouldn't come for the pool). But we were very happy with our stay.",
#  'Ernie at the main desk went above and beyond to make sure we had a great stay.  My daughter and I forgot toothbrushes, and they happily supplied new ones for both.  The breakfast is fresh and a great variety. Love the lime water too, that is available 24/7.',
#  'quiet, clean, roomy bathroom, large shower,',
#  'The location is great.  It is up the street from downtown close but just far enough that it was quiet. The owners were very nice. The pool is great and there is a picnic area with grills.\n',
#  'My husband and I really enjoyed staying here. Nancy and her husband are so nice and make you feel right at home. Anything you needed they were there right away to help. The other guests around our room made us feel like we were home as well. Both the kids and ourselves made new friends. We liked it so much we booked again to stay for our anniversary in a few weeks!',
#  "Room was great! Very clean a/c good! Folks enjoying pool and the owners in residence couldn't have been nicer, even to the point of driving us all into business district after seeing us wIting for Trolly service. Would definitely recommend this place and will rebook again!",
#  'The staff was super friendly. The room was clean and the location of the motel was so close to the town.',
#  'Very clean',
#  'What wasn’t to like. At registration we met Nancy and Jackson after such a long ride to be greeted so warmly',
#  'Very friendly staff. Very clean facility.',
#  'Rooms were big. Very clean.',
#  'The owners are great people.  Very friendly and helpful.',
#  'Owners were very friendly and attentive to the guests and property.',
#  'Fantastic location -friendly team - great lounge area that serves complimentary tea and coffee all day as well as free wine and cheeses from 5pm.Wonderful lounge to escape to after a busy day sightseeing - great breakfast with fresh fruits.',
#  'The staff was attentive without being  intrusive .  Any request was taken care of  immediately .  The best part was enjoying breakfast and wine and cheese in the lovely upstairs lobby.  We made new friends.  The experience was just wonderful!  Also the location was the best as we could walk almost anywhere we wanted to go. I’ll be back.',
#  'Really friendly staff- nothing is too much trouble for them. They were so helpful and attentive. Great location- an oasis of calm just off Time Square ',
#  'The staff were exceptionally friendly.\nThe hotel had great character.\nThe hotel provide free cheese wine and prosecco every night between 5-8 which makes people gather in the lounge area and encourages people to talk to other hotel guests.\nThe location is right on time square and perfect.\nFree wifi. Other hotels charge. ',
#  "Casablanca Hotel in New York is a wonderful place to stay. The staff is very friendly and helpful. The beds and pillows were high quality and very comfortable. The lobby is cozy and welcoming. The building and  Rick's Café were neat and clean. I look forward to another trip to stay at Casablanca Hotel in New York.\rThanks to all the great staff.",
#  'Perhaps a fresher air smell in the room as it rather smelled of stale food, but then again, the air in Manhattan kind of smells like that.  Maybe air purifiers could do the trick? 😊',
#  'Just arrived home after 4 night at Casablanca hotel. We where 5 girls on a City trip to NY, we loved our stay at Casablanca. The complimentary breakfast and the complimentary Wine and cheese was so lovely and a oasis after long hot days of sightseeing and shopping. There is not a single imployer who wasn’t helpfull, and did all to help us with reservations, questions, directions and so on. All where charming and smiling and made a feel at home atmosphere... we had a late flight back to Copenhagen and left our bagage at the hotel, could go back after sightseeing, relax at Ricks Cafe with the Wine, cheese and coffee AND take a shower in a private restroom in the basement because as they told os at the frontdesk; your still at home... you have just checked out off the rooms. Where do you get that kind off service??? So thank you a thousind times Cristian, Victor, all sweet guys at front desk and beautifull girls at breakfast service, you all made our trip to NY memorable, cosy and easy.',
# ...
#  'The rooms were beautiful.',
#  'The bed was very comfortable, the room was very clean and well arranged, and the desk staff were friendly and helpful.',
#  'Excellent hotel!',
#  'clean, comfortable, quiet.',
#  'im an animal lover and although i didnt bring my furbaby, i was so happy to see that pets were allowed to stay in the hotel.',
#  'Fairly new hotel, very clean and comfortable, we were upgraded to a king suite which was roomy and nicely decorated.',
#  'Room very nice, comfortable mattress, clean.  Breakfast had great choice but scrambled eggs too salty.',
#  'Cleanliness of the room.',
#  'Extremely clean, comfortable and beautifully designed room',
#  'Had an excellent stay. Breakfast was great. Room was great. 😊😊',
#  'great place would definitely stay again!',
#  'Could not find a hair dryer in room',
#  'Friendly staff! Hotel very clean! Highly recommend!',
#  "The bathroom floor wasn't as clean as it could have been.",
#  'Friendly staff and clean hotel',
#  'Breakfast area was open, clean, and very nice. Hotel was new/newly updated. Modern feel and high ceilings in the room. No complaints.',
#  'The room was very clean.  Great shower.  Comfortable bed.  We were upgraded to a suite.  The breakfast was excellent.',
#  'The Owners are amazing and their dog! Very friendly and the place is so homey!',
#  'Clean. very comfortable and staff was exceptional. we\rhope to stay there again real soon.',
#  'NANCY THE OWNER WAS THE BEST AND MIKE HER HUSBAND WAS ALSO EXCELLENT WE HAD A GREAT TIME.\rTHANKS\rLIL ,BILL,RAY AND BETH.',
#  'Room is so clean and staff are so sweet',
#  'The owners were great we loved the dog Jacksom',
#  'Very good location, friendly and accommodating staff, clean',
#  'Good location, clean, staff are friendly and accommodating.',
#  'Very clean very cute amazing staff ',
#  'The owners are very accommodating and friendly. Rooms are clean and comfortable and nicely decorated.',
#  'Great place, great staff!',
#  'No coffee pot in room',
#  'Owner very friendly and willing to do anything to make your stay they best it can be.',
#  'The staff was excellent especially finding a Swan made out of towels on our bed. Loved it. :)',
#  'Friendliness of staff and cleanliness!',
#  'It was a great location to the lake , and numerous mountain views.',
#  'well is near to the stores and restaurants. is a good área to stay .',
#  'Clean and maintained very well',
#  'Free coffee was great',
#  'super friendly staff',
#  'Very accommodating staff',
#  'Very good',
#  'Location was great for the price.Staff was very welcoming and friendly',
#  "Wasn't in the middle of the tourist section.  Just far enough away from town.  And quietl ",
#  'Nancy was very friendly and the place was exactly as pictured on the website.',
#  'Owners were very kind',
#  'The owners were so nice and room was very clean!',
#  'Very well kept up. Nice pool. ',
#  'Very clean accommodation',
#  'I did not like that the room did not have a microwave ☹️☹️',
#  'Swimming pool was not heated water,',
#  'Nice friendly people nice area made me feel at home.I booked another stay there',
#  'The staff was very friendly and accommodating. We had a very pleasant stay and would definitely return here!',
#  'Great Owners who really take care of their place.',
#  'Super clean! Comfortable! Nancy (the owner) is so sweet and nice!',
#  'Friendly, highly accommodating staff. Will definitely be staying there again! Thanks Nancy and Mike.',
#  'Nancy was very friendly and accommodating.',
#  'Nice, clean room and friendly staff. Great value!',
#  'everything was perfect. thanks.',
#  'Hosts were absolutely terrific,  helped with all the questions we had and assisted in recommendations of where to go for the weekend.  Truly happy that we went there.',
#  'Swimming pool great for small and older children. Owners are great people, if you forgot something (electronics, clothing etc...) they will contact you and mail it back to you. Thank you Nancy very much... Zoran and Slavko',
#  'Motel is very convenient to town. Rooms are clean and the management is very friendly and accommodating. I have stayed here three separate times and would not hesitate to stay there again. Rates are very, very reasonable.',
#  'The mattress felt like a bed of nails. The sink had a leak and my husband fell and got a concussion. No phones in room to call for help or front desk.',
#  'Super friendly owner who made special accommodations for me and my family, which we greatly appreciated.  Free coffee in the morning and was kept VERY clean.  We enjoyed our stay at this hotel.',
#  'It was exactly what we were looking for. The staff was great, and it was a clean, comfortable place to stay. Everything was kept clean and staff made sure we were comfortable.',
#  'What great staff, friendly and helpful. I had booked here on way back from Niagara where I stayed at the Hilton. The experience at Best Western was 100 times better than the Hilton hands down!!! Staff and fresh chocolate chip cookies in warmers won my kids over super fast. Everything was extremely clean and set a modern vibe.',
#  'Every staff member we met was friendly and sincerely helpful! The hotel lobby was inviting. The room was huge and well laid out. The pool was small but not to chlorinated. The outside chairs and fire pits were also a bonus.',
#  'Room was clean & large... bathroom was clean and large...water pressure in bathroom was excellent..\nBreakfast was beyond excellent... staff was friendly & helpful...',
#  "I rated air conditioning negatively but it was actually heating that we needed.  There were two problems with it.  These are common problems, but I didn't expect them in a brand new hotel.\r1) It was super noisy and woke us up each time it went on through the night. \r2) It had high temperature fluctuations.  I couldn't set the heater to any setting that made the room not swing to an uncomfortably cool temperature.",
#  'Breakfast was wonderful. The eggs were fluffy, the bacon was crisp as I like it. The cinnamon bread was wonderful as were the banana chocolate chip muffins. And we enjoyed the pumpkin spice waffles as well.  The room was large and clean. The a/c worked well.  The staff were very accommodating and helpful and nice.',
#  'Clean and new.  The only thing that could have made it better is if it was on the lake.  But so very close to town (Hammondsport) and the water, that is was not an inconvenience at all.  Would stay again.',
#  'The room was large and clean, brand new! Staff was very friendly, especially the breakfast ladies. They insured that we had everything we needed and were very friendly! Had fire pits outside to sit by very relaxing. Lovely hotel, very comfortable!',
#  'all the staff was extremely friendly always spoke and smiling. The rooms were great, largeenoughto move around and very clean. the continental breakfast was very good and the staff was very willing to assist you. \rvery nice place',
#  'The staff was so friendly and accommodating!  The town is beautiful!  Room immaculate!  Fire pit a big plus!  Very affordable!  Highly recommend! We will definitely visit Hammondsport again and stay at Best Western Plus!',
#  'Clean, spacious room and delicious breakfast!',
#  'Yes',
#  'Clean, Friendly, Good Breakfast',
#  "I love staying here I will stay here every timer I'm in the area",
#  'Very crisp and clean.  Friendly welcome with local advice',
#  'The bed was extremely firm, and felt like we were sleeping on the floor. We cut our trip short by a day home so we didn’t have to sleep on it again.',
#  'Every nice experience. All things good. Good lication just out of town. Staff very friendly.',
#  'The staff was very friendly and helpful.  Facilities were clean. Great place especially for the price. ',
#  'Cleanliness. Breakfast\rWonderful staff',
#  'The facility was very clean and all staff was friendly and professional.',
#  'Breakfast was very good',
#  'The location was perfect and the place was very clean. We loved the breakfast and the pool.',
#  'Good breakfast. Friendly and accommodating staff. Clean and comfortable hotel.',
#  'The hotel was very clean,  staff was accommodating to my dietary needs -\rexcellent stay!',
#  'Clean and modern with an outdoor fire pit to sit around',
#  'Perfect hotel to stay in for touring the Finger Lakes Wine region',
#  'Pool was could',
#  'Without a doubt the staff was the most helpful and friendly out of all the places we have ever stayed!  If you are traveling with a pet it is the only hotel to use in the area.',
#  'My room was filthy my bed Head dirt And hair between the sheets and the mattress cover a bunch of dust all over the place even in the dresser I was a little upset and the only thing they did for me was change the sheets and they gave me a bottle water and a cookie what a joke',
#  'Staff greeted us with warm smiles and pleasant demeanors. This was most welcome after a long drive to our destination. The room was big but it could have been a little cleaner in the bathroom. The location in Clifton Park was perfect for us. Breakfast was good too. We overall enjoyed our stay very much and would come back to this hotel and recommend it.',
#  'I enjoyed how they treated my family and myself like..well family.  they were patient with my very active children, accommodated all our needs which were many and were extremely polite.  the breakfast was awesome by the way as well.',
#  'Most of the breakfast was a disappointment. The waffles were doughy and the orange juice was watery. \rThe extra blanket that was needed for the pull out couch bed was not sufficient! I used TWO of them ( they are very thin) and did NOT keep me warm at all. I was cold all night despite setting the room temp at 73 degrees.',
#  'It’s a nice, quiet hotel. I’ve stayed here twice and both times it was a great experience! I would highly recommend this hotel and would stay there again!',
#  'was traveling with family (no children under 18) - we had a dirt bike on a trailer and we were worried about security - we did see a security guard on the property and in the morning the bike was fine',
#  "Bed was good. Room was clean . Pictures in room were cool to bad didn't say where they were taken . We left and thought we left something behind called back they checked and later we found it in car girls at front desk very helpful. 😀😀",
#  'This hotel is very new and really nice. We enjoyed the comfy bed, the room size and the complimentary breakfast.  Everything is nice and clean.  We stayed here as a midway point on our way up to Vermont.',
#  'I love everything about this property. The location is super convenient (very walkable and right on the 6 line), the staff are super friendly and helpful, the rooms are clean and comfortable, the complimentary continental breakfast is great with varied options and good coffee. This is my second stay here and have been very impressed both times. Excellent value for money.',
#  'We had a wonderful stay with our toddler in the hotel Giraffe. Definitely the best location in the city, close to Madison Park, great restaurants and shopping. Staff is friendly and helpful, room was cleaned every day early per our request, and the snacks were always available. We will be back :)',
#  'All seating accommodations uncomfortable.  When we relax in the evening we like to read so comfort and lighting is very important.  Sheets and towels should not be changed daily.  Ecology should be an important factor!',
#  'All staff was extra attentive. Parking was easy. The details and little touches made hotel giraffe special. Cocktail hours, slippers, lots of closet space, comfort and friendly. Turn down service with music playing upon return in room. Breakfast is continental but with a catering effect.',
#  'We liked everything about this hotel but especially the staff attitude and helpfulness. The location is great (lower midtown) near most activities and yet away from the craziness of Times Square.',
#  'The service was World Class . The person that owns this establishment should be awarded Best Hotel in NY. I have been traveling to NY for the last 40years and this was the best experience ever!',
#  'Very friendly staff. Great wine and cheese reception with piano. My daughter got sick and the staff was helpful, made sure she had herb tea, and gave us a refund because we had to leave one night early. The room was very comfortable, but the street noise (trucks) got loud in the middle of the night.',
#  'Intimate hotel with excellent service',
#  'Great friendly well located hotel ',
#  'Room was very comfortable, morning breakfast was a great timesaver.',
#  'Everything super clean very warm and comfortable. Pleasant staff with state of the art coffee expresso machine. ',
#  'Breakfast',
#  'Location! Service))) staff was absolutely brilliant ',
#  'Customer friendly (can’t do enough) and looked after guests really well. Evening jazz over wine and cheese was a good touch. ',
#  'Clean, pleasant, friendly . A cool serene spot to recover from nyc heat in summer.',
#  'The boutique intimacy with warmth and great service.',
#  'Outstanding. Very friendly and convenient.',
#  'The hotel staff was very friendly and helpful, the rooms were lovely and it was great value compared to other hotels in NYC.',
#  'Bottles of shampoo, conditioner....too difficult to get product out.',
#  'Fantastic location! Friendly staff and adorable balcony rooms',
#  'Excellent bed, large and quiet room, and most of all very friendly staff.',
#  'Location, service, people',
#  'Complimentary wine and cheese every evening. Friendly service.',
#  'Clean. Caring staff. Convenient location.',
#  'clean, tidy, warm welcome, excellent continental b/fast, coffee available all day! Very comfortable bed.',
#  'I asked for a small coffee maker , was called about special requests days before my stay, and when i arrived there was still no coffee maker...',
#  'Excellent, healthy breakfast.  Very nice staff.  Comfy, warm room.  Everything perfect!',
#  'Noisy',
#  'Comfy beds',
#  'Great staff and very helpful.  Great location and walkable to tourist sites and stores.',
#  'Breakfast  and Happy Hour included and the hardworking staff that remember me and smile as they serve up treats in the lobby.',
#  'Very friendly staff very efficient \rGood facilities\rLovely ‘complimentary ‘ cheese and wine',
#  "Best stay I've had in New York in years",
#  'The ambiance, friendliness and free coffee and tea 24/7',
#  'The only downside is it’s a small hotel without some of the amenities of larger properties.',
#  'The hotel provides possibly every thing  a traveller may require.\rThe free snacks and drinks are great.',
#  'Quiet',
#  'Everything and everybody worked the way it should in a very good business hotel wihilst maintaining the overall chic design boutique atmosphere.',
#  'Front desk staff were AMAZING! Super clean rooms. Love how the TV knew my name. Only negative thing is that the pool area is extremely chlorinated. It was very over powering. But not a big deal since I really didnt spend time down there. Best linens and bathroom! Did I mention how clean this place is?!?!',
#  'we liked the balcony,the view of Lake George,the Bistro.Every thing was top notch. The staff was friendly,caring,professional people . Looking forward to going back.',
#  'The beds were comfortable!  Onsite parking.  Plenty of seating area in lobby/library/lounge area and cafe.  Front desk convenient with friendly people.',
#  'Loud pipe in room raddled all night. Pillows weren’t great. Did not get room that was booked through booking.com',
#  'The price was a little high for winter',
#  'Room rates are higher than other hotels',
#  'The staff was always friendly and accommodating! Great experience from parking to checking out.',
#  'The view of the lake from our balcony was amazing.',
#  'LOVED the modern décor! Room was spacious and bed SO comfortable!',
#  'Bed was awesome, room clean. Restaurant food excellent. View from the room was spectacular. Easy walk to everything.',
#  'Good location, very friendly staff. Big comfortable rooms and very clean.',
#  ...]

# %%
# Convert to list
data = all_rev#df.content.values.tolist()

# # Remove Emails
# data = [re.sub('\S*@\S*\s?', '', sent) for sent in data]
data = [re.sub('/', ' ', sent) for sent in data]
# Remove new line characters
data = [re.sub('\s+', ' ', sent) for sent in data]

# Remove distracting single quotes
data = [re.sub("\'", "", sent) for sent in data]

print(data[:1])
# Out:
# ['Desk staff excellent. Friendly and helpful. Breakfast was great. Bed very comfortable and loved the living kitchenette space in addition to the bedroom.']

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

print(data_words[:1])
# Out:
# [['desk', 'staff', 'excellent', 'friendly', 'and', 'helpful', 'breakfast', 'was', 'great', 'bed', 'very', 'comfortable', 'and', 'loved', 'the', 'living', 'kitchenette', 'space', 'in', 'addition', 'to', 'the', 'bedroom']]

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
print(trigram_mod[bigram_mod[data_words[0]]])
# Out:
# ['desk', 'staff', 'excellent', 'friendly', 'and', 'helpful', 'breakfast', 'was', 'great', 'bed', 'very', 'comfortable', 'and', 'loved', 'the', 'living', 'kitchenette', 'space', 'in', 'addition', 'to', 'the', 'bedroom']

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# python3 -m spacy download en
nlp = spacy.load('en')#, disable=['parser', 'ner'])

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

print(data_lemmatized[:1])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-70-77dbc2e984b5> in <module>
#      10
#      11 # Do lemmatization keeping only noun, adj, vb, adv
# ---> 12 data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])
#      13
#      14 print(data_lemmatized[:1])
#
# <ipython-input-69-a9dac53f8cd2> in lemmatization(texts, allowed_postags)
#      13     texts_out = []
#      14     for sent in texts:
# ---> 15         doc = nlp(" ".join(sent))
#      16         texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
#      17     return texts_out
#
# ~/anaconda3/lib/python3.6/site-packages/spacy/language.py in __call__(self, text, disable)
#     344             if not hasattr(proc, '__call__'):
#     345                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 346             doc = proc(doc)
#     347             if doc is None:
#     348                 raise ValueError(Errors.E005.format(name=name))
#
# pipeline.pyx in spacy.pipeline.Tagger.__call__()
#
# pipeline.pyx in spacy.pipeline.Tagger.predict()
#
# ~/anaconda3/lib/python3.6/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     159             Must match expected shape
#     160         '''
# --> 161         return self.predict(x)
#     162
#     163     def pipe(self, stream, batch_size=128):
#
# ~/anaconda3/lib/python3.6/site-packages/thinc/api.py in predict(self, X)
#      53     def predict(self, X):
#      54         for layer in self._layers:
# ---> 55             X = layer(X)
#      56         return X
#      57
#
# ~/anaconda3/lib/python3.6/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     159             Must match expected shape
#     160         '''
# --> 161         return self.predict(x)
#     162
#     163     def pipe(self, stream, batch_size=128):
#
# ~/anaconda3/lib/python3.6/site-packages/thinc/api.py in predict(seqs_in)
#     291     def predict(seqs_in):
#     292         lengths = layer.ops.asarray([len(seq) for seq in seqs_in])
# --> 293         X = layer(layer.ops.flatten(seqs_in, pad=pad))
#     294         return layer.ops.unflatten(X, lengths, pad=pad)
#     295
#
# ~/anaconda3/lib/python3.6/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     159             Must match expected shape
#     160         '''
# --> 161         return self.predict(x)
#     162
#     163     def pipe(self, stream, batch_size=128):
#
# ~/anaconda3/lib/python3.6/site-packages/thinc/api.py in predict(self, X)
#      53     def predict(self, X):
#      54         for layer in self._layers:
# ---> 55             X = layer(X)
#      56         return X
#      57
#
# ~/anaconda3/lib/python3.6/site-packages/thinc/neural/_classes/resnet.py in __call__(self, X)
#      13
#      14     def __call__(self, X):
# ---> 15         return X + self._layers[0](X)
#      16
#      17     def begin_update(self, X, drop=0.):
#
# ~/anaconda3/lib/python3.6/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     159             Must match expected shape
#     160         '''
# --> 161         return self.predict(x)
#     162
#     163     def pipe(self, stream, batch_size=128):
#
# ~/anaconda3/lib/python3.6/site-packages/thinc/api.py in predict(self, X)
#      53     def predict(self, X):
#      54         for layer in self._layers:
# ---> 55             X = layer(X)
#      56         return X
#      57
#
# ~/anaconda3/lib/python3.6/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     159             Must match expected shape
#     160         '''
# --> 161         return self.predict(x)
#     162
#     163     def pipe(self, stream, batch_size=128):
#
# ~/anaconda3/lib/python3.6/site-packages/thinc/neural/_classes/layernorm.py in predict(self, X)
#      42
#      43     def predict(self, X):
# ---> 44         X = self.child.predict(X)
#      45         N, mu, var = _get_moments(self.ops, X)
#      46         Xh = _forward(self.ops, X, mu, var)
#
# ~/anaconda3/lib/python3.6/site-packages/thinc/neural/_classes/maxout.py in predict(self, X__BI)
#      58     def predict(self, X__BI):
#      59         W = self.W.reshape((self.nO * self.nP, self.nI))
# ---> 60         X__BOP = self.ops.batch_dot(X__BI, W)
#      61         X__BOP += self.b.reshape((self.nO*self.nP,))
#      62         X__BOP = X__BOP.reshape((X__BOP.shape[0], self.nO, self.nP))
#
# KeyboardInterrupt:

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# View
print(corpus[:1])

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=30, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
print(lda_model.print_topics())
doc_lda = lda_model[corpus]

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis

# %% [markdown]
# ## Building LDA Mallet Model
#
# So far you have seen Gensim’s inbuilt version of the LDA algorithm. Mallet’s version, however, often gives a better quality of topics.
#
# Gensim provides a wrapper to implement Mallet’s LDA from within Gensim itself. You only need to download the zipfile, unzip it and provide the path to mallet in the unzipped directory to gensim.models.wrappers.LdaMallet. See how I have done this below.

# %%
mallet_path = '/home/argha/Desktop/mallet-2.0.8/bin/mallet' # update this path
ldamallet = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=20, id2word=id2word)

# Show Topics
pprint(ldamallet.show_topics(formatted=False))

# Compute Coherence Score
coherence_model_ldamallet = CoherenceModel(model=ldamallet, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()
print('\nCoherence Score: ', coherence_ldamallet)

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=id2word)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
# Can take a long time to run.
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=data_lemmatized, start=2, limit=40, step=6)
# Show graph
limit=40; start=2; step=6;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))

# %%
# Select the model and print the topics
optimal_model = model_list[3]
model_topics = optimal_model.show_topics(formatted=False)
pprint(optimal_model.print_topics(num_words=10))

# %%
def format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=data):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=optimal_model, corpus=corpus, texts=data)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

# Show
df_dominant_topic.head(10)

# %%
# Group top 5 sentences under each topic
sent_topics_sorteddf_mallet = pd.DataFrame()

sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, 
                                             grp.sort_values(['Perc_Contribution'], ascending=[0]).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Text"]

# Show
sent_topics_sorteddf_mallet.head()

Most Representative Topic For Each Document

# %%
# Number of Documents for Each Topic
topic_counts = df_topic_sents_keywords['Dominant_Topic'].value_counts()

# Percentage of Documents for Each Topic
topic_contribution = round(topic_counts/topic_counts.sum(), 4)

# Topic Number and Keywords
topic_num_keywords = df_topic_sents_keywords[['Dominant_Topic', 'Topic_Keywords']]

# Concatenate Column wise
df_dominant_topics = pd.concat([topic_num_keywords, topic_counts, topic_contribution], axis=1)

# Change Column names
df_dominant_topics.columns = ['Dominant_Topic', 'Topic_Keywords', 'Num_Documents', 'Perc_Documents']

# Show
df_dominant_topics
